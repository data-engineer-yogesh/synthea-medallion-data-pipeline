# %% [markdown]
# Data Profiling
#
# - Verified the schema after ingestion.
# - Confirmed the total number of records.
# - Reviewed summary statistics to identify potential outliers.
# - Checked for missing values before applying transformations.

# %% [markdown]
# DataProfiling the for tyhe patients table

# %%
df_patients = spark.read.table("syntheamedalliondatapipeline.01_bronze.patients")

# %% [markdown]
# df.summary().display() works in Databricks and is equivalent to display(df.summary())
#
# Both display the summary statistics in the Databricks notebook

# %%
df_patients.summary().display()

# %%
#Checking data types

df_patients.printSchema()

# %%
#display(df_patients)  

# View data and use Data Profile (if available)
# Interactive exploration and visual Data Profile
# We get here Exception: dbutils.data.summarize() is not supported on serverless compute.Due to free version
# Out:
# Databricks data profile. Run in Databricks to view.

# %% [markdown]
# DataProfiling the for tyhe encounters table

# %%
df_encounters = spark.read.table("syntheamedalliondatapipeline.01_bronze.encounters")

df_encounters.summary().display()

# %%
#Checking data types

df_encounters.printSchema()

# %% [markdown]
# DataProfiling the for tyhe conditions table

# %%
df_conditions = spark.read.table("syntheamedalliondatapipeline.01_bronze.conditions")

df_conditions.summary().display()

#Checking data types

df_conditions.printSchema()

# %% [markdown]
# DataProfiling the for tyhe medications table

# %%
df_medications = spark.read.table("syntheamedalliondatapipeline.01_bronze.medications")

df_medications.summary().display()

#Checking data types

df_medications.printSchema()

# %% [markdown]
# DataProfiling the for tyhe procedures table

# %%
df_procedures = spark.read.table("syntheamedalliondatapipeline.01_bronze.procedures")

df_procedures.summary().display()

#Checking data types

df_procedures.printSchema()

# %% [markdown]
# DataProfiling the for tyhe providers table

# %%
df_providers = spark.read.table("syntheamedalliondatapipeline.01_bronze.providers")

df_providers.summary().display()

#Checking data types

df_providers.printSchema()
