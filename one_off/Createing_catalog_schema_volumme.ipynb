# %% [markdown]
# create unit_catalog
#
# **Note**: We are using the free edition, so the managed location feature is not available. Therefore, it will be created in Databricks.

# %%
spark.sql("create catalog if not exists SyntheaMedallionDataPipeline")

# %% [markdown]
# create schema
# - landing
# - bronze
# - siver
# - glod

# %%
spark.sql("create schema if not exists SyntheaMedallionDataPipeline.00_landing")
spark.sql("create schema if not exists SyntheaMedallionDataPipeline.01_bronze")
spark.sql("create schema if not exists SyntheaMedallionDataPipeline.02_silver")
spark.sql("create schema if not exists SyntheaMedallionDataPipeline.03_gold")

# %% [markdown]
# create volume

# %%
spark.sql("create volume if not exists SyntheaMedallionDataPipeline.00_landing.data_sources");
